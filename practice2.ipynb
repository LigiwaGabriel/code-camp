# %% [markdown]
# DataSeries, DataFrames

# %%
import pandas as pd

# %%
students_data={
    "maths":[80,75,67,90],
    "english":[90,85,70,80],
    "science":[60,65,88,77],
    "french":[60,99,89,73]

}
students=pd.DataFrame(students_data)
students
# Out:
#    maths  english  science  french
# 0     80       90       60      60
# 1     75       85       65      99
# 2     67       70       88      89
# 3     90       80       77      73

# %%
students.shape
# Out:
# (4, 4)

# %%
students.head
# Out:
# <bound method NDFrame.head of    maths  english  science  french
# 0     80       90       60      60
# 1     75       85       65      99
# 2     67       70       88      89
# 3     90       80       77      73>

# %%
students.tail
# Out:
# <bound method NDFrame.tail of    maths  english  science  french
# 0     80       90       60      60
# 1     75       85       65      99
# 2     67       70       88      89
# 3     90       80       77      73>

# %%
students.describe
# Out:
# <bound method NDFrame.describe of    maths  english  science  french
# 0     80       90       60      60
# 1     75       85       65      99
# 2     67       70       88      89
# 3     90       80       77      73>

# %%
students.describe()
# Out:
#            maths    english    science    french
# count   4.000000   4.000000   4.000000   4.00000
# mean   78.000000  81.250000  72.500000  80.25000
# std     9.626353   8.539126  12.556539  17.23127
# min    67.000000  70.000000  60.000000  60.00000
# 25%    73.000000  77.500000  63.750000  69.75000
# 50%    77.500000  82.500000  71.000000  81.00000
# 75%    82.500000  86.250000  79.750000  91.50000
# max    90.000000  90.000000  88.000000  99.00000

# %%
students["maths"].mean()
# Out:
# np.float64(78.0)

# %%
students["english"].mode()[0]
# Out:
# np.int64(70)

# %%
students["science"].median()
# Out:
# np.float64(71.0)

# %%
students["maths"].mode()[0]
# Out:
# np.int64(67)

# %%
students["maths"].std()
# Out:
# np.float64(9.626352718795768)

# %%
students["french"].var()
# Out:
# np.float64(296.9166666666667)

# %%
students["french"].max()
# Out:
# np.int64(99)

# %%
students["maths"].max()-students["maths"].min()
# Out:
# np.int64(23)

# %%
lower_quartile=students["maths"].quantile(0.25)
lower_quartile
# Out:
# np.float64(73.0)

# %%
upper_quartile=students["maths"].quantile(0.75)
upper_quartile
# Out:
# np.float64(82.5)

# %%
import numpy as np

# %%
lower_quartile2=np.percentile(students["english"],90)
lower_quartile2
# Out:
# np.float64(88.5)

# %%
lower_quartile2=np.percentile(students["maths"],90)
lower_quartile2
# Out:
# np.float64(87.0)

# %%
students=pd.read_csv("StudentsPerformance.csv")
students
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
